# %%
from trustcall import create_extractor
from langchain_ollama import ChatOllama
from pydantic import BaseModel, Field
from typing import List
from langchain_core.messages import AIMessage
from langchain_core.tools import tool
from langchain_ollama import ChatOllama

# %%
class MetaAnalysisInsights():
    """Use these attributes mentioned as keys to generate a strutured output of MetaAnalysisInsights"""
    """Structured representation of project metadata analysis"""
    project_type: str = Field(
        description="Type/category of the project (e.g., web framework, data processing, ML library, etc.)")
    domain: str = Field(
        description="Domain or field the project belongs to (e.g., web development, data science, DevOps, etc.)")
    architectural_patterns: List[str] = Field(description="Main architectural patterns typically used in such projects")
    expected_components: List[str] = Field(description="Expected high-level components/modules based on project type")
    technology_stack: List[str] = Field(description="Main technologies, frameworks, and libraries used")
    architectural_bias: str = Field(
        description="Guidance on how to interpret and organize components for this project type")

# %%
llm = ChatOllama(model="llama3.2:latest",base_url="http://localhost:11434",temperature=0)
extractor = create_extractor(llm,tools=[MetaAnalysisInsights],tool_choice=MetaAnalysisInsights.__name__)

# %%
meta_input = """
**Project Type**: Application virtualization and containerization tool. It's a desktop application (Electron-based) designed to run Windows applications on a Linux host with seamless integration.
**Domain**: Cross-platform compatibility, desktop virtualization, containerization, user experience enhancement, and system integration.
**Technology Stack**:
*   **Core Application**: Electron (for the GUI and main application logic)
*   **Virtualization/Containerization**: Docker (for containerizing the Windows VM), KVM (underlying virtualization technology)
*   **Remote Display/Integration**: FreeRDP (for remote desktop connection and RemoteApp protocol)
*   **Guest OS Component**: WinBoat Guest Server (custom server running inside the Windows VM, likely Go-based)
*   **Development/Build**: NodeJS, Go
**Architectural Patterns**:
*   **Client-Server Architecture**: The Electron application acts as a client orchestrating the Windows environment, which includes a "Guest Server" component.
*   **Containerization Pattern**: Utilizes Docker to encapsulate the Windows virtual machine environment.
*   **Virtualization Pattern**: Leverages KVM for hardware-assisted virtualization of the Windows guest.
*   **Remote Display/Application Integration**: Employs FreeRDP and Windows's RemoteApp protocol to integrate individual Windows applications into the Linux desktop environment.
**Expected Components**:
1.  **WinBoat Electron Application**: The main user interface and orchestration layer, responsible for managing the lifecycle of the Windows VM, user settings, and interaction.
2.  **Docker/KVM Management Module**: Handles the creation, configuration, starting, and stopping of the Docker container running the Windows VM, interacting with KVM.
3.  **Windows Virtual Machine (Guest OS)**: The actual Windows operating system instance running within the Docker container.
4.  **WinBoat Guest Server**: A service or application running inside the Windows VM, responsible for communicating with the Electron app, providing data, and potentially managing Windows-specific operations.
5.  **FreeRDP Integration Layer**: Manages the remote desktop connection and the rendering of individual Windows applications as native Linux windows.
6.  **Filesystem Sharing Module**: Facilitates seamless file sharing and integration between the Linux host and the Windows guest.
7.  **Installation & Setup Module**: Automates the initial setup and configuration of the Windows environment within the container.
**Architectural Bias**: The project exhibits a strong **hybrid client-server and containerized virtualization bias**. The core architectural components should be organized around the interaction between the Electron-based host application and the containerized Windows guest. Key focus areas for component organization and diagram representation should be:
*   The clear separation and communication flow between the Electron UI/orchestrator and the backend virtualization/containerization layers.
*   The role of the "WinBoat Guest Server" as a critical bridge between the host and guest environments.
*   The integration points for FreeRDP to achieve the "seamless integration" of Windows applications.
*   The lifecycle management of the Dockerized Windows VM.
"""

# %%
result = extractor.invoke(meta_input)

# %%
print(result['messages'])
# Out:
# [AIMessage(content='Below is a **high‑level, component‑centric view** of the WinBoat stack that captures the key flows you mentioned.  \nFeel free to let me know if you’d like a more detailed sequence diagram, a UML package diagram, or a visual diagram in a specific format (PlantUML, Mermaid, etc.).\n\n---\n\n## 1.  High‑Level Architecture Overview\n\n```\n+--------------------------------------------------------------+\n|                     WinBoat Electron App                    |\n|  (UI + Orchestrator)                                         |\n|  ├─ Settings & User Profile                                 |\n|  ├─ VM Lifecycle Manager (Docker/KVM)                       |\n|  ├─ Guest‑Server Communicator (IPC / HTTP / gRPC)           |\n|  ├─ FreeRDP Client (RemoteApp)                              |\n|  └─ Filesystem Share Manager (NFS / SMB / virtio‑fs)        |\n+--------------------------------------------------------------+\n            ▲                 ▲                 ▲\n            │                 │                 │\n            │                 │                 │\n            │                 │                 │\n+-----------+-----------------+-----------------+-----------+\n|           |                 |                 |           |\n|  Docker   |                 |                 |  Guest    |\n|  Container|                 |                 |  Server   |\n|  (KVM VM) |                 |                 |  (Go)     |\n|  (Windows)|                 |                 |  (WinAPI) |\n|           |                 |                 |           |\n+-----------+-----------------+-----------------+-----------+\n            │                 │                 │\n            │                 │                 │\n            │                 │                 │\n+-----------+-----------------+-----------------+-----------+\n|           |                 |                 |           |\n|  FreeRDP  |                 |                 |  Guest OS |\n|  (RDP)    |                 |                 |  (Windows)|\n|           |                 |                 |           |\n+-----------+-----------------+-----------------+-----------+\n```\n\n### Core Interaction Paths\n\n| Path | Direction | Purpose |\n|------|-----------|---------|\n| **Electron ↔ Docker/KVM** | Client → Server | VM lifecycle: create, start, stop, snapshot, delete. |\n| **Electron ↔ Guest Server** | Client ↔ Server | Control plane: send commands (e.g., launch app, query status), receive telemetry. |\n| **Electron ↔ FreeRDP** | Client → Guest OS | Render individual RemoteApp windows as native Linux windows. |\n| **Electron ↔ Filesystem Share** | Client ↔ Guest OS | Seamless file access (e.g., `virtio‑fs`, SMB, NFS). |\n| **Guest Server ↔ Guest OS** | Server ↔ OS | Native Windows APIs (WinAPI, COM, etc.) to launch apps, manage resources. |\n| **Guest Server ↔ FreeRDP** | Server ↔ RDP | Optional: expose RDP session metadata, clipboard sync, etc. |\n\n---\n\n## 2.  Component Breakdown\n\n| Component | Technology | Responsibility | Key Interfaces |\n|-----------|------------|----------------|----------------|\n| **WinBoat Electron App** | Electron + Node.js | UI, user settings, orchestration | IPC (Electron), REST/gRPC to Guest Server, Docker CLI, FreeRDP client |\n| **Docker/KVM Management Module** | Docker, libvirt, KVM | VM provisioning, networking, storage | Docker API, libvirt API, `virsh` commands |\n| **Windows VM (Guest OS)** | Windows 10/11 (or Server) | Runtime for Windows apps | RDP, SMB, WinAPI |\n| **WinBoat Guest Server** | Go | Bridge between Electron and Windows | HTTP/JSON or gRPC, WinAPI wrappers |\n| **FreeRDP Integration Layer** | FreeRDP | RemoteApp rendering, clipboard, audio | RDP protocol, X11/Wayland integration |\n| **Filesystem Sharing Module** | virtio‑fs / SMB / NFS | File sync between host & guest | Mount points, `virtio‑fs` daemon |\n| **Installation & Setup Module** | Node.js + Go scripts | Automate VM image build, Dock ...

# %%
print(result['messages'][0].content)
# Out:
# Below is a **complete, “ready‑to‑draw” view** of the WinBoat stack that you can drop straight into a diagramming tool (PlantUML, Mermaid, Lucidchart, etc.).
# It is split into three logical layers:
#
# | Layer | Responsibility | Key Components | Communication |
# |-------|----------------|----------------|---------------|
# | **1. Host / Orchestrator** | Electron UI + orchestration logic | *WinBoat‑Electron* (renderer + main) | IPC (Electron), REST/WS to Guest Server |
# | **2. Container / Virtualization** | Docker/KVM runtime | *Docker‑KVM‑Manager*, *Docker‑Image* (Windows VM) | Docker API, libvirt/KVM, shared volumes |
# | **3. Guest / Remote Display** | Windows VM + RemoteApp | *WinBoat‑Guest‑Server*, *FreeRDP* client, *Windows OS* | RDP (FreeRDP → Guest), SMB/IPC for file share, HTTP/WS for Guest Server |
#
# ---
#
# ## 1. High‑Level Architecture Diagram (PlantUML)
#
# ```plantuml
# @startuml
# skinparam backgroundColor #f8f8f8
# skinparam componentStyle rectangle
#
# title WinBoat – Hybrid Client‑Server + Containerized Virtualization
#
# package "Host / Orchestrator" {
#   component "WinBoat‑Electron" as Electron
# }
#
# package "Container / Virtualization" {
#   component "Docker/KVM Manager" as DockerMgr
#   component "Docker Image (Windows VM)" as WinVM
# }
#
# package "Guest / Remote Display" {
#   component "WinBoat Guest Server" as GuestSrv
#   component "FreeRDP Client" as FreeRDP
#   component "Windows OS" as WinOS
# }
#
# ' Connections
# Electron --> DockerMgr : Docker API / libvirt
# DockerMgr --> WinVM : start/stop, config
# WinVM --> GuestSrv : HTTP/WS (guest‑server API)
# GuestSrv --> FreeRDP : RDP (RemoteApp)
# FreeRDP --> WinOS : RDP session
# FreeRDP --> Electron : RDP events (window, clipboard)
# Electron --> GuestSrv : REST/WS (settings, lifecycle)
# Electron --> DockerMgr : lifecycle commands
# DockerMgr --> WinVM : shared volumes (filesystem)
# WinVM --> GuestSrv : SMB/IPC for file share
#
# @enduml
# ```
#
# > **Tip** – Paste the above into any PlantUML renderer (e.g., <https://www.plantuml.com/plantuml>) to get a clean diagram.
#
# ---
#
# ## 2. Component Breakdown & Interaction Flow
#
# | Component | Core Tech | Key APIs / Protocols | Typical Flow |
# |-----------|-----------|----------------------|--------------|
# | **WinBoat‑Electron** | Electron (Node.js + Chromium) | IPC (main ↔ renderer), HTTP/WS, Docker CLI | User clicks “Start VM” → IPC → DockerMgr → Docker API → WinVM |
# | **Docker/KVM Manager** | Docker Engine + libvirt (via `docker` CLI or Go SDK) | Docker REST API, libvirt XML | Receives lifecycle commands → creates container → mounts host volumes → starts KVM VM |
# | **Docker Image (Windows VM)** | Windows Server Core + KVM hyper‑visor | Guest‑Server API (HTTP/WS), SMB | Container boots → Guest Server registers → exposes RDP endpoint |
# | **WinBoat Guest Server** | Go (or .NET) | HTTP/WS (REST), RDP‑over‑WebSocket (optional) | Handles VM‑side commands (e.g., “list apps”), pushes telemetry to Electron |
# | **FreeRDP Client** | FreeRDP (C) | RDP (TCP 3389), RemoteApp protocol | Electron spawns FreeRDP → connects to Guest Server → renders each RemoteApp as a native Linux window |
# | **Filesystem Sharing** | SMB / Docker bind mounts | SMB/CIFS, Docker volume | Host → Docker volume → Guest → SMB share → Guest → SMB client (Windows) |
# | **Installation & Setup Module** | Node.js + Go scripts | Dockerfile, init scripts | Automates image build, pre‑configures Guest Server, installs RDP drivers |
#
# ---
#
# ## 3. Lifecycle Sequence (Mermaid)
#
# ```mermaid
# sequenceDiagram
#     participant UI as WinBoat‑Electron
#     participant Docker as Docker/KVM Manager
#     participant VM as Docker Image (Windows VM)
#     participant Guest as WinBoat Guest Server
#     participant RDP as FreeRDP Client
#
#     UI->>Docker: startVM()
#     Docker->>VM: docker run --privileged --volume=host:/guest
#     VM-->>Docker: VM booted
#     Docker->>Guest: register()
#     Guest->>RDP: startRemoteApp("App.exe")
#     RDP->>Guest: RDP handshake
#     Guest->>RDP: RDP stream
#     RDP->>UI: window events, clipboard
#     Note over UI: User interacts with native Linux window
# ```
#
# ---
#
# ## 4. Key Design Decisions & Rationale
#
# | Decision | Why it matters |
# |----------|----------------|
# | **Electron as orchestrator** | Gives a native‑looking UI, cross‑platform, easy to bundle with Node.js tooling. |
# | **Docker + KVM** | Docker gives reproducible images; KVM provides hardware acceleration. |
# | **Guest Server as bridge** | Keeps the VM “thin” – only needs to expose a lightweight API; all heavy lifting (RDP, file share) stays in the VM. |
# | **FreeRDP for RemoteApp** | Open‑source, supports RemoteApp, can be embedded in Electron via a WebSocket bridge. |
# | **Shared volumes + SMB** | Fast, POSIX‑compatible file sharing; SMB is the de‑facto standard for Windows‑Linux interop. |
# | **REST/WS for control** | Decouples UI from VM; can be extended to CLI or mobile clients. |
#
# ---
#
# ## 5. Suggested Folder Layout
#
# ```
# /winboat
# ├─ /electron          # Electron main + renderer
# │   ├─ main.js
# │   ├─ renderer.js
# │   └─ package.json
# ├─ /docker
# │   ├─ Dockerfile
# │   ├─ entrypoint.sh
# │   └─ winvm-config/
# ├─ /guest-server
# │   ├─ main.go
# │   ├─ api/
# │   └─ config/
# ├─ /free-rdp
# │   └─ rdp-wrapper.js   # Node wrapper for FreeRDP
# ├─ /shared
# │   └─ volumes/
# └─ /scripts
#     ├─ setup.sh
#     └─ cleanup.sh
# ```
#
# ---
#
# ## 6. Security & Performance Tips
#
# | Area | Recommendation |
# |------|----------------|
# | **VM isolation** | Run Docker container with `--privileged` only if necessary; otherwise use `--cap-add=SYS_ADMIN` + `--security-opt apparmor:unconfined`. |
# | **Network** | Expose RDP only on localhost; use SSH tunnel or VPN for remote access. |
# | **Guest Server** | Use TLS for REST/WS; authenticate via JWT or mutual TLS. |
# | **File sharing** | Mount only required directories; use `noexec`/`nosuid` flags for security. |
# | **Resource limits** | Set CPU/memory limits on Docker container to avoid host starvation. |
# | **Logging** | Centralize logs from Electron, Docker, Guest Server, and FreeRDP for troubleshooting. |
#
# ---
#
# ## 7. Next Steps
#
# 1. **Generate the diagram** – copy the PlantUML snippet into a renderer.
# 2. **Validate the flow** – run a quick prototype: start the Electron app, trigger `startVM()`, watch the Docker container spin up, and confirm FreeRDP renders a RemoteApp.
# 3. **Add monitoring** – expose Prometheus metrics from Guest Server and Docker Manager.
# 4. **Package** – bundle the Electron app with the Docker image (using `docker save` + `electron-builder`).
#
# Feel free to tweak the diagram or component names to match your internal naming conventions. Happy building!
